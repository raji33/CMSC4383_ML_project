# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.11.0

# %%
import pandas as pd


url = "../datasets/Housing_chicago_dataset.csv"
dataset = pd.read_csv(url)
dataset
# Out:
#      Unnamed: 0  interest  vaccancy      cpi     price          value  \
# 0    2008-02-02      5.68      10.1  212.174  238000.0  224141.415394
# 1    2008-02-09      5.67      10.1  212.687  236000.0  224141.415394
# 2    2008-02-16      5.72      10.1  212.687  235000.0  224141.415394
# 3    2008-02-23      6.04      10.1  212.687  245000.0  224141.415394
# 4    2008-03-01      6.24      10.1  212.687  244500.0  225551.318122
# ..          ...       ...       ...      ...       ...            ...
# 755  2022-12-10      6.33       5.8  298.990  275000.0  287684.170594
# 756  2022-12-17      6.31       5.8  298.990  275000.0  287684.170594
# 757  2022-12-24      6.27       5.8  298.990  265000.0  287684.170594
# 758  2022-12-31      6.42       5.8  298.990  275000.0  287684.170594
# 759  2023-01-07      6.48       5.8  300.536  260000.0  289469.478392
#
#          adj_price
# 0    112172.085175
# 1    110961.177693
# 2    110491.003211
# 3    115192.748029
# 4    114957.660788
# ...

# %%
import pandas as pd
import numpy as np
from keras.datasets import mnist
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout


#split the inputs and the outputs 
input_df = dataset[["interest", "vaccancy", "cpi", "value", "adj_price"]]


# Set the target/label data to just the survived column
target_df = dataset[["price"]]



input_train_df, input_test_df, target_train_df, target_test_df = train_test_split(
    input_df, 
    target_df, 
    test_size=0.2
)


#convert to numpy arrays
input_train_numpy = input_train_df.to_numpy()
input_test_numpy = input_test_df.to_numpy()

target_train_numpy = target_train_df.to_numpy()
target_test_numpy = target_test_df.to_numpy()

# %%
target_train_numpy
# Out:
# array([[225000.],
#        [202500.],
#        [235000.],
#        [212750.],
#        [252500.],
#        [248000.],
#        [255000.],
#        [191000.],
#        [184950.],
#        [190000.],
#        [213000.],
#        [231900.],
#        [260000.],
#        [230000.],
#        [220000.],
#        [210000.],
#        [255000.],
#        [195000.],
#        [228750.],
#        [310000.],
#        [235000.],
#        [208000.],
#        [250000.],
#        [199000.],
#        [245000.],
#        [275000.],
#        [299000.],
#        [228000.],
#        [225000.],
#        [215000.],
#        [236000.],
#        [193000.],
#        [229000.],
#        [221500.],
#        [222000.],
#        [190000.],
#        [224500.],
#        [237000.],
#        [205000.],
#        [310000.],
#        [210000.],
#        [205000.],
#        [207000.],
#        [213000.],
#        [190000.],
#        [203000.],
#        [250000.],
#        [175250.],
#        [247500.],
#        [177700.],
# ...

# %%
#model initialization

model = Sequential()

# model.add(Dense(512, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.25))


model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


model.fit(input_train_numpy, target_train_numpy,
          epochs=2,
          validation_data=(input_test_numpy, target_test_numpy))
model.summary()
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 16
#       5 # model.add(Dense(512, activation='relu'))
#       6 # model.add(Dropout(0.5))
#       7 # model.add(Dense(256, activation='relu'))
#       8 # model.add(Dropout(0.25))
#      11 model.compile(optimizer='Adam',
#      12               loss='categorical_crossentropy',
#      13               metrics=['accuracy'])
# ---> 16 model.fit(input_train_numpy, target_train_numpy,
#      17           epochs=2,
#      18           validation_data=(input_test_numpy, target_test_numpy))
#      19 model.summary()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
# ...
